# %% [markdown]
# # Package Initialization Test
#
# This notebook serves as a basic test to verify that the `pump` library is installed and importable. It also checks the package metadata and verifies that the `pint` unit registry is working correctly.

# %%
# Import the package and verify its name
import pump
pump.__name__
# Out:
# 'pump'

# %%
# Check the exposed public API (__all__)
pump.__all__
# Out:
# ['CONTEXT',
#  'PerformanceChecker',
#  'Fluid',
#  'ReportGenerator',
#  'TestPoint',
#  'quantity_factory',
#  'Water',
#  'DesignPoint',
#  'BasePoint',
#  'STANDARD_UNITS',
#  'Point',
#  'PerformanceCurve',
#  'Q_']

# %%
# Verify the package author
pump.__author__
# Out:
# 'Cristofer Antoni Souza Costa'

# %%
# Verify the package version
pump.__version__
# Out:
# '0.0.1'

# %%
# Inspect the complete package namespace
dir(pump)
# Out:
# ['BasePoint',
#  'CONTEXT',
#  'DesignPoint',
#  'Fluid',
#  'PerformanceChecker',
#  'PerformanceCurve',
#  'Point',
#  'Q_',
#  'ReportGenerator',
#  'STANDARD_UNITS',
#  'TestPoint',
#  'Water',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__email__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__status__',
#  '__version__',
#  'performance_curve',
#  'point',
#  'quantity_factory',
#  'utilities']

# %%
# Test the unit registry (Q_) and quantity_factory functions
Q_ = pump.Q_
pump.quantity_factory(Q_(10, "km"))
# Out:
# <Quantity(10000.0, 'meter')>
